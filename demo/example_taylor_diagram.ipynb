# %% [markdown]
# ## Example plot

# %%
import numpy as np
from bokeh.plotting import output_file, save, show, output_notebook
from ESMBenchmarkViz import taylor_diagram

# %%
# Enable Bokeh output in the notebook
output_notebook()
# Out:
#     <style>
#         .bk-notebook-logo {
#             display: block;
#             width: 20px;
#             height: 20px;
#             background-image: url(data:image/png;base64,...);
#         }
#     </style>
#     <div>
#         <a href="https://bokeh.org" target="_blank" class="bk-notebook-logo"></a>
#         <span id="ddcfd22c-fa32-4525-ac54-cba7437b4bbf">Loading BokehJS ...</span>
#     </div>

# %%
# Sample data
std_devs = [0.3, 0.8, 1.2, 0.9, 1.1, 1.2, 1, 2]
correlations = [0.5, 0.6, 0.7, 0.8, 0.9, 0.95, 1, 0.99]
names = ['Model A', 'Model B', 'Model C', 'Model D', 'Model E', 'Model F', 'Model G', 'Model H']
refstd = 1.25

# Figure settings
normalize = True  # Set Trur or False
step = 0.2

# Plot
p = taylor_diagram(std_devs, correlations, names, refstd, normalize=normalize, step=step)
# Out:
#   <div id="b54117b5-60d4-421e-af52-8ce3bfd78c6d" data-root-id="p1001" style="display: contents;"></div>

# %%
# set output to static HTML file
output_file(filename="interactive_taylor_diagram.html", title="Interactive Taylor Diagram")

# save the results to a file
save(p)

# Result: [`interactive_taylor_diagram.html`](interactive_taylor_diagram.html)
# Out:
# '/Users/lee1043/Documents/Research/git/ESMBenchmarkViz/ESMBenchmarkViz/taylor_diagram/interactive_taylor_diagram.html'

# %%
from ESMBenchmarkViz import taylor_diagram

std_devs = [0.8, 1.0, 1.2]  # Standard deviations of models

correlations = [0.9, 0.85, 0.7]  # Correlation coefficients

names = ["Model A", "Model B", "Model C"]  # Names of models

refstd = 1.0  # Standard deviation of reference model

colormap = ["red", "green", "blue"]  # Colors of models

taylor_diagram(std_devs, correlations, names, refstd, colormap=colormap)
# Out:
#   <div id="e2989632-701a-4f21-a2ea-f45329e95d25" data-root-id="p2215" style="display: contents;"></div>
# figure(id='p2215', ...)

# %%
from ESMBenchmarkViz import taylor_diagram
# Standard deviations of models
std_devs = [0.3, 0.8, 1.2, 0.9, 1.1, 1.2, 1, 2]
# Correlation coefficients
correlations = [0.5, 0.6, 0.7, 0.8, 0.9, 0.95, 1, 0.99]
# Names of models
names = ['Model A', 'Model B', 'Model C', 'Model D', 'Model E', 'Model F', 'Model G', 'Model H']
# Standard deviation of reference model
refstd = 1.25

taylor_diagram(std_devs, correlations, names, refstd)
# Out:
#   <div id="e17da10e-2e32-4a20-81c1-12bd98b23c5a" data-root-id="p1735" style="display: contents;"></div>
# figure(id='p1735', ...)
